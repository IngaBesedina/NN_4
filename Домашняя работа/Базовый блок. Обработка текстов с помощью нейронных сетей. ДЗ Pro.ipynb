# %% [markdown]
# Дорогой студент!
#
# В данном домашнем задании предоставляется возможность поработать с задачей по распознаванию позитивных и негативных отзывы людей по автомобилю Tesla. База для обучения содержит два текстовых файла с рядом строчных отзывов с мнением людей об автомобиле Tesla, соответственно негативного и позитивного содержания. Ссылка на скачивание базы уже включена в ноутбук задания.
#
#
# Необходимо выполнить следующие действия:
#
#   1. Загрузите саму базу по ссылке и подговьте файлы базы для обработки.
#   2. Создайте обучающую и проверочную выборки, обратив особое внимание на балансировку базы: количество примеров каждого класса должно быть примерно одного порядка.
#   3. Подготовьте выборки для обучения и обучите сеть. Добейтесь результата точности сети в 85-90% на проверочной выборке.

# %% [markdown]
# **Импорт библиотек, загрузка базы и подготовка её к предобработке.**

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from tensorflow.keras import utils

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    SpatialDropout1D,
    BatchNormalization,
    Embedding,
    Flatten,
    Activation,
)
from tensorflow.keras.layers import Dense, Dropout, SpatialDropout1D, BatchNormalization, Embedding, Flatten, Activation

from tensorflow.keras.preprocessing.text import Tokenizer

from tensorflow.keras.preprocessing.sequence import pad_sequences

import gdown

import os

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l7/tesla.zip', None, quiet=True)
# Out:
# 'tesla.zip'

# %% [markdown]
# **Деление общей базы отзывов на данные для обучения и проверки.**

# %%
# Распаковка архива в папку writers
# !unzip -qo tesla.zip -d tesla/

# Просмотр содержимого папки
# !ls tesla
# Out:
# 'Негативный отзыв.txt'	'Позитивный отзыв.txt'

# %% [markdown]
# **Загрузка текста из файлов, преобразование в одну строку.**

# %%
# Объявляем функции для чтения файла. На вход отправляем путь к файлу
def read_text(file_name):

  # Задаем открытие нужного файла в режиме чтения
  read_file = open(file_name, 'r')

  # Читаем текст
  text = read_file.read()

  # Переносы строки переводим в пробелы
  text = text.replace("\n", " ")

  # Возвращаем текст файла
  return text

# Объявляем интересующие нас классы
class_names = ["Негативный отзыв", "Позитивный отзыв"]

# Считаем количество классов
num_classes = len(class_names)

# %% [markdown]
# **Тексты в один список.**

# %%
import os
# Создаём список под тексты для обучающей выборки
texts_list = []

# Циклом проводим итерацию по текстовым файлам в папке отзывов
for j in os.listdir('/content/tesla/'):

  # Добавляем каждый файл в общий список для выборки
        texts_list.append(read_text('/content/tesla/' + j))

        # Выводим на экран сообщение о добавлении файла
        print(j, 'добавлен в обучающую выборку')
# Out:
# Негативный отзыв.txt добавлен в обучающую выборку
# Позитивный отзыв.txt добавлен в обучающую выборку

# %%
# Узнаем объём каждого текста в словах и символах
texts_len = [len(text) for text in texts_list]

# Устанавливаем "счётчик" номера текста
t_num = 0

# Выводим на экран  информационное сообщение
print(f'Размеры текстов по порядку (в токенах):')

# Циклом проводим итерацию по списку с объёмами текстов
for text_len in texts_len:

  # Запускаем "счётчик" номера текста
  t_num += 1

  # Выводим на экран сообщение о номере и объёме текста
  print(f'Текст №{t_num}: {text_len}')
# Out:
# Размеры текстов по порядку (в токенах):
# Текст №1: 134535
# Текст №2: 213381

# %% [markdown]
# Далее рассчитаем, сколько символов составит 80% объёма каждого текста, чтобы по полученному индексу отделить эти 80% на обучающую и оставшиеся 20% на проверочную выборку. Эти значения необходимы для подготовки деления на выборки слайсингом по индексу.

# %%
# Создаём список с вложенным циклом по длинам текстов, где i - 100% текста, i/5 - 20% текста
train_len_shares = [(i - round(i/5)) for i in texts_len]

# Устанавливаем "счётчик" номера текста
t_num = 0

# Циклом проводим итерацию по списку с объёмами текстов равными 80% от исходных
for train_len_share in train_len_shares:

  # Запускаем "счётчик" номера текста
  t_num += 1

  # Выводим на экран сообщение о номере и объёме текста в 80% от исходного
  print(f'Доля 80% от текста №{t_num}: {train_len_share} символов')
# Out:
# Доля 80% от текста №1: 107628 символов
# Доля 80% от текста №2: 170705 символов

# %% [markdown]
# Импортируем функцию **chain()** для добавления текстов в каждую выборку.
#
# ---
#  Дополнительная информация: ([База знаний УИИ  - **"Методы работы со списками: функция chain( )**"](https://colab.research.google.com/drive/1KJKg_WYD8Vq63cciOMBEEAhFpyPv0A0V?usp=sharing/))
#
# ---
#
# Производём нарезку (метод слайсинга) по полученному ранее индексу для формирования текстов отдельно для обучающей(80%) и проверочной(20%) выборок:

# %%
from itertools import chain
# Ваше решение

# %%
text_train = []
text_validate = []
# Ваше решение
for i, text in enumerate(texts_list):
    text_train.append(text[:train_len_shares[i]])
    text_validate.append(text[train_len_shares[i]:])

# %%
VOCAB_SIZE = 20_000
WIN_SIZE = 1000
WIN_HOPE = 150


def split_sequence(sequence, win_size, hop):
    return [
        sequence[i : i + win_size] for i in range(0, len(sequence) - win_size + 1, hop)
    ]

def vectorize_sequence(seq_list, win_size, hop):
    class_count = len(seq_list)

    x, y = [], []

    for cls in range(class_count):
        vectors = split_sequence(seq_list[cls], win_size, hop)
        x += vectors
        y += [utils.to_categorical(cls, class_count)] * len(vectors)

    return np.array(x), np.array(y)

# %%
tokenizer = Tokenizer(
    num_words=VOCAB_SIZE,
    filters='!"#$%&()*+,-–—./…:;<=>?@[\\]^_`{|}~«»\t\n\xa0\ufeff',
    lower=True,
    split=" ",
    oov_token="неизвестное_слово",
    char_level=False,
)
tokenizer.fit_on_texts(texts_list)
seq_train = tokenizer.texts_to_sequences(text_train)
seq_test = tokenizer.texts_to_sequences(text_validate)

x_train, y_train = vectorize_sequence(seq_train, WIN_SIZE, WIN_HOPE)
x_test, y_test = vectorize_sequence(seq_test, WIN_SIZE, WIN_HOPE)
x_train = tokenizer.sequences_to_matrix(x_train.tolist()).astype("float16")
x_test = tokenizer.sequences_to_matrix(x_test.tolist()).astype("float16")

# %%
# Преобразуем one-hot обратно в метки классов
train_labels = np.argmax(y_train, axis=1)
test_labels = np.argmax(y_test, axis=1)

# Подсчёт с помощью bincount
train_counts = np.bincount(train_labels)
test_counts = np.bincount(test_labels)

# Вывод результатов
print("Обучающая выборка:")
for cls, count in enumerate(train_counts):
    print(f"Класс {cls}: {count} окон")

print("\nТестовая выборка:")
for cls, count in enumerate(test_counts):
    print(f"Класс {cls}: {count} окон")
# Out:
# Обучающая выборка:
# Класс 0: 107 окон
# Класс 1: 166 окон
#
# Тестовая выборка:
# Класс 0: 23 окон
# Класс 1: 38 окон

# %%
from tensorflow.keras.optimizers import Adam
model = Sequential(
    [
        Input((VOCAB_SIZE,)),
        Dense(200, activation="relu"),
        Dropout(0.4),
        Dense(100),
        Dropout(0.4),
        Dense(2, activation="softmax"),
    ]
)

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 200)            │     4,000,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │           202 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,020,502 (15.34 MB)
#  Trainable params: 4,020,502 (15.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=150,
    batch_size=16,
    validation_data=(x_test, y_test),
    verbose=1,
)
# Out:
# Epoch 1/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.7443 - loss: 0.4536 - val_accuracy: 1.0000 - val_loss: 0.0853
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.0950e-04 - val_accuracy: 0.9344 - val_loss: 0.1565
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.8280e-05 - val_accuracy: 0.9344 - val_loss: 0.1708
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 7.2918e-06 - val_accuracy: 0.9344 - val_loss: 0.1561
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 7.6725e-06 - val_accuracy: 0.9344 - val_loss: 0.1440
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.0247e-06 - val_accuracy: 0.9344 - val_loss: 0.1393
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.8469e-07 - val_accuracy: 0.9344 - val_loss: 0.1363
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.4442e-06 - val_accuracy: 0.9344 - val_loss: 0.1338
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.6706e-06 - val_accuracy: 0.9344 - val_loss: 0.1315
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.2190e-05 - val_accuracy: 0.9344 - val_loss: 0.1135
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.6275e-05 - val_accuracy: 0.9344 - val_loss: 0.1245
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.8196e-06 - val_accuracy: 0.9344 - val_loss: 0.1161
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4089e-06 - val_accuracy: 0.9344 - val_loss: 0.1170
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.8782e-07 - val_accuracy: 0.9344 - val_loss: 0.1175
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4015e-06 - val_accuracy: 0.9344 - val_loss: 0.1097
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.7267e-06 - val_accuracy: 0.9344 - val_loss: 0.1182
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 2.0572e-07 - val_accuracy: 0.9344 - val_loss: 0.1208
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.7808e-07 - val_accuracy: 0.9344 - val_loss: 0.1187
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.1996e-07 - val_accuracy: 0.9344 - val_loss: 0.1136
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.8923e-05 - val_accuracy: 0.9672 - val_loss: 0.0994
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.8018e-07 - val_accuracy: 0.9672 - val_loss: 0.0965
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.6327e-06 - val_accuracy: 0.9672 - val_loss: 0.0934
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5903e-06 - val_accuracy: 0.9672 - val_loss: 0.0904
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 9.0788e-07 - val_accuracy: 0.9672 - val_loss: 0.0887
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.6680e-07 - val_accuracy: 0.9672 - val_loss: 0.0874
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.2615e-05 - val_accuracy: 0.9672 - val_loss: 0.0786
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 5.4699e-06 - val_accuracy: 0.9672 - val_loss: 0.0903
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7828e-06 - val_accuracy: 0.9672 - val_loss: 0.0887
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1998e-07 - val_accuracy: 0.9672 - val_loss: 0.0883
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4318e-07 - val_accuracy: 0.9672 - val_loss: 0.0859
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7721e-06 - val_accuracy: 0.9508 - val_loss: 0.0982
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1317e-06 - val_accuracy: 0.9344 - val_loss: 0.1165
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.1885e-07 - val_accuracy: 0.9344 - val_loss: 0.1210
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.4491e-07 - val_accuracy: 0.9344 - val_loss: 0.1230
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.6650e-06 - val_accuracy: 0.9508 - val_loss: 0.0976
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3903e-07 - val_accuracy: 0.9508 - val_loss: 0.0853
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.3060e-05 - val_accuracy: 0.9672 - val_loss: 0.0729
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.8649e-07 - val_accuracy: 0.9672 - val_loss: 0.0705
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.6643e-06 - val_accuracy: 0.9672 - val_loss: 0.0676
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.1922e-08 - val_accuracy: 0.9672 - val_loss: 0.0667
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9528e-07 - val_accuracy: 0.9672 - val_loss: 0.0674
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.6352e-07 - val_accuracy: 0.9672 - val_loss: 0.0749
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 7.6460e-08 - val_accuracy: 0.9672 - val_loss: 0.0766
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.4024e-07 - val_accuracy: 0.9672 - val_loss: 0.0757
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.3531e-07 - val_accuracy: 0.9672 - val_loss: 0.0762
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.1735e-07 - val_accuracy: 0.9508 - val_loss: 0.0770
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.2047e-07 - val_accuracy: 0.9508 - val_loss: 0.0783
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.3277e-08 - val_accuracy: 0.9508 - val_loss: 0.0800
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.8373e-07 - val_accuracy: 0.9508 - val_loss: 0.0810
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.2884e-07 - val_accuracy: 0.9508 - val_loss: 0.0812
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3255e-07 - val_accuracy: 0.9508 - val_loss: 0.0797
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.5255e-07 - val_accuracy: 0.9508 - val_loss: 0.0796
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.8964e-07 - val_accuracy: 0.9508 - val_loss: 0.0797
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.7276e-08 - val_accuracy: 0.9508 - val_loss: 0.0798
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.0685e-07 - val_accuracy: 0.9508 - val_loss: 0.0797
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.0500e-07 - val_accuracy: 0.9508 - val_loss: 0.0795
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.5587e-07 - val_accuracy: 0.9508 - val_loss: 0.0798
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.8515e-06 - val_accuracy: 0.9508 - val_loss: 0.0772
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.1420e-07 - val_accuracy: 0.9508 - val_loss: 0.0771
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.0744e-07 - val_accuracy: 0.9672 - val_loss: 0.0759
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.2280e-08 - val_accuracy: 0.9672 - val_loss: 0.0757
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1964e-08 - val_accuracy: 0.9672 - val_loss: 0.0757
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.9615e-08 - val_accuracy: 0.9672 - val_loss: 0.0756
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.2098e-08 - val_accuracy: 0.9672 - val_loss: 0.0751
# Epoch 65/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.0604e-08 - val_accuracy: 0.9672 - val_loss: 0.0751
# Epoch 66/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.3659e-08 - val_accuracy: 0.9672 - val_loss: 0.0751
# Epoch 67/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.8578e-06 - val_accuracy: 0.9672 - val_loss: 0.0758
# Epoch 68/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7768e-07 - val_accuracy: 0.9508 - val_loss: 0.0764
# Epoch 69/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.1058e-08 - val_accuracy: 0.9508 - val_loss: 0.0767
# Epoch 70/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.7499e-08 - val_accuracy: 0.9508 - val_loss: 0.0769
# Epoch 71/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 5.1491e-08 - val_accuracy: 0.9508 - val_loss: 0.0770
# Epoch 72/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.2106e-07 - val_accuracy: 0.9508 - val_loss: 0.0762
# Epoch 73/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 2.7685e-07 - val_accuracy: 0.9672 - val_loss: 0.0746
# Epoch 74/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.1804e-07 - val_accuracy: 0.9672 - val_loss: 0.0716
# Epoch 75/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.5804e-08 - val_accuracy: 0.9672 - val_loss: 0.0715
# Epoch 76/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.2993e-08 - val_accuracy: 0.9672 - val_loss: 0.0714
# Epoch 77/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.9022e-08 - val_accuracy: 0.9672 - val_loss: 0.0714
# Epoch 78/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 7.1840e-08 - val_accuracy: 0.9672 - val_loss: 0.0717
# Epoch 79/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.6354e-07 - val_accuracy: 0.9672 - val_loss: 0.0716
# Epoch 80/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.0711e-08 - val_accuracy: 0.9672 - val_loss: 0.0700
# Epoch 81/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 6.2578e-08 - val_accuracy: 0.9672 - val_loss: 0.0696
# Epoch 82/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.9396e-08 - val_accuracy: 0.9672 - val_loss: 0.0697
# Epoch 83/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 4.6919e-08 - val_accuracy: 0.9672 - val_loss: 0.0699
# Epoch 84/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 9.9594e-07 - val_accuracy: 0.9672 - val_loss: 0.0707
# Epoch 85/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.3870e-08 - val_accuracy: 0.9672 - val_loss: 0.0722
# Epoch 86/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.3160e-07 - val_accuracy: 0.9672 - val_loss: 0.0726
# Epoch 87/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.5709e-06 - val_accuracy: 0.9672 - val_loss: 0.0749
# Epoch 88/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 3.9076e-08 - val_accuracy: 0.9508 - val_loss: 0.0778
# Epoch 89/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.9635e-08 - val_accuracy: 0.9508 - val_loss: 0.0784
# Epoch 90/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.0651e-07 - val_accuracy: 0.9508 - val_loss: 0.0786
# Epoch 91/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.8164e-07 - val_accuracy: 0.9508 - val_loss: 0.0790
# Epoch 92/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.4277e-08 - val_accuracy: 0.9508 - val_loss: 0.0793
# Epoch 93/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4259e-06 - val_accuracy: 0.9508 - val_loss: 0.0822
# Epoch 94/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.7796e-08 - val_accuracy: 0.9508 - val_loss: 0.0833
# Epoch 95/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.0955e-07 - val_accuracy: 0.9508 - val_loss: 0.0839
# Epoch 96/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.6752e-08 - val_accuracy: 0.9508 - val_loss: 0.0846
# Epoch 97/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.5733e-09 - val_accuracy: 0.9508 - val_loss: 0.0846
# Epoch 98/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.9935e-07 - val_accuracy: 0.9508 - val_loss: 0.0861
# Epoch 99/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.0636e-09 - val_accuracy: 0.9508 - val_loss: 0.0866
# Epoch 100/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 3.4277e-07 - val_accuracy: 0.9508 - val_loss: 0.0871
# Epoch 101/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.1598e-08 - val_accuracy: 0.9508 - val_loss: 0.0872
# Epoch 102/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.3258e-07 - val_accuracy: 0.9508 - val_loss: 0.0861
# Epoch 103/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.1534e-07 - val_accuracy: 0.9508 - val_loss: 0.0845
# Epoch 104/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.4002e-08 - val_accuracy: 0.9508 - val_loss: 0.0846
# Epoch 105/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.7896e-08 - val_accuracy: 0.9508 - val_loss: 0.0848
# Epoch 106/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.3968e-09 - val_accuracy: 0.9508 - val_loss: 0.0850
# Epoch 107/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.1700e-08 - val_accuracy: 0.9508 - val_loss: 0.0851
# Epoch 108/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 8.0653e-10 - val_accuracy: 0.9508 - val_loss: 0.0852
# Epoch 109/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9886e-07 - val_accuracy: 0.9508 - val_loss: 0.0854
# Epoch 110/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.3188e-08 - val_accuracy: 0.9508 - val_loss: 0.0853
# Epoch 111/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 9.2301e-08 - val_accuracy: 0.9508 - val_loss: 0.0854
# Epoch 112/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.3965e-08 - val_accuracy: 0.9508 - val_loss: 0.0854
# Epoch 113/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 7.9840e-08 - val_accuracy: 0.9508 - val_loss: 0.0854
# Epoch 114/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.0326e-09 - val_accuracy: 0.9508 - val_loss: 0.0854
# Epoch 115/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.0848e-08 - val_accuracy: 0.9508 - val_loss: 0.0855
# Epoch 116/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.5074e-08 - val_accuracy: 0.9508 - val_loss: 0.0856
# Epoch 117/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.8396e-07 - val_accuracy: 0.9508 - val_loss: 0.0859
# Epoch 118/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 8.9057e-07 - val_accuracy: 0.9508 - val_loss: 0.0827
# Epoch 119/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.1900e-08 - val_accuracy: 0.9508 - val_loss: 0.0773
# Epoch 120/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9132e-07 - val_accuracy: 0.9508 - val_loss: 0.0771
# Epoch 121/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.1711e-08 - val_accuracy: 0.9508 - val_loss: 0.0777
# Epoch 122/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.8090e-08 - val_accuracy: 0.9508 - val_loss: 0.0776
# Epoch 123/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4817e-08 - val_accuracy: 0.9508 - val_loss: 0.0775
# Epoch 124/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 9.6116e-07 - val_accuracy: 0.9508 - val_loss: 0.0839
# Epoch 125/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.2002e-08 - val_accuracy: 0.9508 - val_loss: 0.0857
# Epoch 126/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.6956e-08 - val_accuracy: 0.9508 - val_loss: 0.0858
# Epoch 127/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 2.6649e-07 - val_accuracy: 0.9508 - val_loss: 0.0860
# Epoch 128/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.9087e-07 - val_accuracy: 0.9508 - val_loss: 0.0828
# Epoch 129/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.7985e-07 - val_accuracy: 0.9508 - val_loss: 0.0799
# Epoch 130/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.7080e-08 - val_accuracy: 0.9508 - val_loss: 0.0797
# Epoch 131/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.1132e-07 - val_accuracy: 0.9508 - val_loss: 0.0793
# Epoch 132/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 9.1045e-07 - val_accuracy: 0.9508 - val_loss: 0.0809
# Epoch 133/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.1712e-08 - val_accuracy: 0.9508 - val_loss: 0.0830
# Epoch 134/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.1081e-08 - val_accuracy: 0.9508 - val_loss: 0.0829
# Epoch 135/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.2767e-09 - val_accuracy: 0.9508 - val_loss: 0.0829
# Epoch 136/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.6553e-09 - val_accuracy: 0.9508 - val_loss: 0.0829
# Epoch 137/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.9216e-08 - val_accuracy: 0.9508 - val_loss: 0.0828
# Epoch 138/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 5.7818e-08 - val_accuracy: 0.9508 - val_loss: 0.0831
# Epoch 139/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.7822e-08 - val_accuracy: 0.9508 - val_loss: 0.0831
# Epoch 140/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.9343e-09 - val_accuracy: 0.9508 - val_loss: 0.0831
# Epoch 141/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.9359e-07 - val_accuracy: 0.9508 - val_loss: 0.0861
# Epoch 142/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.6809e-08 - val_accuracy: 0.9508 - val_loss: 0.0871
# Epoch 143/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.0798e-09 - val_accuracy: 0.9508 - val_loss: 0.0873
# Epoch 144/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 2.0176e-08 - val_accuracy: 0.9508 - val_loss: 0.0870
# Epoch 145/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.8108e-08 - val_accuracy: 0.9508 - val_loss: 0.0872
# Epoch 146/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.8892e-07 - val_accuracy: 0.9508 - val_loss: 0.0882
# Epoch 147/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.5851e-08 - val_accuracy: 0.9508 - val_loss: 0.0884
# Epoch 148/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.2666e-09 - val_accuracy: 0.9508 - val_loss: 0.0885
# Epoch 149/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 8.7818e-09 - val_accuracy: 0.9508 - val_loss: 0.0886
# Epoch 150/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.6038e-07 - val_accuracy: 0.9508 - val_loss: 0.0883

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
fig.suptitle("График процесса обучения модели")
ax1.plot(
    history.history["accuracy"], label="Доля верных ответов на обучающем наборе"
)
ax1.plot(
    history.history["val_accuracy"],
    label="Доля верных ответов на проверочном наборе",
)
ax1.xaxis.get_major_locator().set_params(integer=True)
ax1.set_xlabel("Эпоха обучения")
ax1.set_ylabel("Доля верных ответов")
ax1.legend()

ax2.plot(history.history["loss"], label="Ошибка на обучающем наборе")
ax2.plot(history.history["val_loss"], label="Ошибка на проверочном наборе")
ax2.xaxis.get_major_locator().set_params(integer=True)
ax2.set_xlabel("Эпоха обучения")
ax2.set_ylabel("Ошибка")
ax2.legend()
plt.show()
